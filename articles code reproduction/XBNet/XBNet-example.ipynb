# %%
# !pip install --upgrade git+https://github.com/tusharsarkar3/XBNet.git
# Out:
# Collecting git+https://github.com/tusharsarkar3/XBNet.git
#   Cloning https://github.com/tusharsarkar3/XBNet.git to /tmp/pip-req-build-it1f1qo2
#   Running command git clone -q https://github.com/tusharsarkar3/XBNet.git /tmp/pip-req-build-it1f1qo2
# Requirement already satisfied, skipping upgrade: sklearn==0.0 in /root/venv/lib/python3.7/site-packages (from XBNet==1.4.6) (0.0)
# Collecting numpy==1.21.2
#   Downloading numpy-1.21.2-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
#      |████████████████████████████████| 15.7 MB 5.7 MB/s
# Collecting pandas==1.3.3
#   Downloading pandas-1.3.3-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.3 MB)
#      |████████████████████████████████| 11.3 MB 10.7 MB/s
# Collecting matplotlib==3.4.3
#   Downloading matplotlib-3.4.3-cp37-cp37m-manylinux1_x86_64.whl (10.3 MB)
#      |████████████████████████████████| 10.3 MB 26.2 MB/s
# Collecting torch==1.9.0
#   Downloading torch-1.9.0-cp37-cp37m-manylinux1_x86_64.whl (831.4 MB)
#      |████████████████████████████████| 831.4 MB 1.4 kB/s
# Collecting xgboost==1.4.2
#   Downloading xgboost-1.4.2-py3-none-manylinux2010_x86_64.whl (166.7 MB)
#      |████████████████████████████████| 166.7 MB 23 kB/s
# Collecting tqdm==4.62.2
#   Downloading tqdm-4.62.2-py2.py3-none-any.whl (76 kB)
#      |████████████████████████████████| 76 kB 5.9 MB/s
# Requirement already satisfied, skipping upgrade: scikit-learn in /shared-libs/python3.7/py/lib/python3.7/site-packages (from sklearn==0.0->XBNet==1.4.6) (1.0.2)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7.3 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from pandas==1.3.3->XBNet==1.4.6) (2.8.2)
# Requirement already satisfied, skipping upgrade: pytz>=2017.3 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pandas==1.3.3->XBNet==1.4.6) (2021.3)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib==3.4.3->XBNet==1.4.6) (0.11.0)
# Requirement already satisfied, skipping upgrade: pyparsing>=2.2.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from matplotlib==3.4.3->XBNet==1.4.6) (3.0.7)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib==3.4.3->XBNet==1.4.6) (1.3.2)
# Requirement already satisfied, skipping upgrade: pillow>=6.2.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib==3.4.3->XBNet==1.4.6) (9.0.1)
# Requirement already satisfied, skipping upgrade: typing-extensions in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from torch==1.9.0->XBNet==1.4.6) (4.1.1)
# Requirement already satisfied, skipping upgrade: scipy in /shared-libs/python3.7/py/lib/python3.7/site-packages (from xgboost==1.4.2->XBNet==1.4.6) (1.7.3)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from scikit-learn->sklearn==0.0->XBNet==1.4.6) (1.1.0)
# Requirement already satisfied, skipping upgrade: threadpoolctl>=2.0.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from scikit-learn->sklearn==0.0->XBNet==1.4.6) (3.1.0)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas==1.3.3->XBNet==1.4.6) (1.16.0)
# Building wheels for collected packages: XBNet
#   Building wheel for XBNet (setup.py) ... done
#   Created wheel for XBNet: filename=XBNet-1.4.6-py3-none-any.whl size=12334 sha256=234dc33af0e3841d73ea7dd8a9671e7889f26222103062a4b4749a84297a3be4
#   Stored in directory: /tmp/pip-ephem-wheel-cache-e0irrymu/wheels/23/c6/c1/0ee5a35c7a28c4dd8db05ce1407d1ccb0cfb036216e0c2ff92
# Successfully built XBNet
# ERROR: torchvision 0.11.3 has requirement torch==1.10.2, but you'll have torch 1.9.0 which is incompatible.
# ERROR: thinc 8.0.13 has requirement typing-extensions<4.0.0.0,>=3.7.4.1; python_version < "3.8", but you'll have typing-extensions 4.1.1 which is incompatible.
# ERROR: tensorflow 2.4.1 has requirement numpy~=1.19.2, but you'll have numpy 1.21.2 which is incompatible.
# ERROR: tensorflow 2.4.1 has requirement six~=1.15.0, but you'll have six 1.16.0 which is incompatible.
# ERROR: tensorflow 2.4.1 has requirement typing-extensions~=3.7.4, but you'll have typing-extensions 4.1.1 which is incompatible.
# ERROR: spacy 3.2.2 has requirement typing-extensions<4.0.0.0,>=3.7.4; python_version < "3.8", but you'll have typing-extensions 4.1.1 which is incompatible.
# Installing collected packages: numpy, pandas, matplotlib, torch, xgboost, tqdm, XBNet
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.5
#     Not uninstalling numpy at /shared-libs/python3.7/py/lib/python3.7/site-packages, outside environment /root/venv
#     Can't uninstall 'numpy'. No files were found to uninstall.
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.2.5
#     Not uninstalling pandas at /shared-libs/python3.7/py/lib/python3.7/site-packages, outside environment /root/venv
#     Can't uninstall 'pandas'. No files were found to uninstall.
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.5.1
#     Not uninstalling matplotlib at /shared-libs/python3.7/py/lib/python3.7/site-packages, outside environment /root/venv
#     Can't uninstall 'matplotlib'. No files were found to uninstall.
#   Attempting uninstall: torch
#     Found existing installation: torch 1.10.2
#     Not uninstalling torch at /shared-libs/python3.7/py/lib/python3.7/site-packages, outside environment /root/venv
#     Can't uninstall 'torch'. No files were found to uninstall.
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.62.3
#     Not uninstalling tqdm at /shared-libs/python3.7/py/lib/python3.7/site-packages, outside environment /root/venv
#     Can't uninstall 'tqdm'. No files were found to uninstall.
# Successfully installed XBNet-1.4.6 matplotlib-3.4.3 numpy-1.21.2 pandas-1.3.3 torch-1.9.0 tqdm-4.62.2 xgboost-1.4.2
# WARNING: You are using pip version 20.1.1; however, version 22.0.3 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %%
import torch
import numpy as np


from XBNet.training_utils import training,predict
from XBNet.models import XBNETClassifier
from XBNet.run import run_XBNET

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

# %%
import matplotlib.pyplot as plt

# %%
data = load_iris()
x = data.data
y = data.target
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size= 0.2, random_state=43)

# %%
model = XBNETClassifier(x_train,y_train,num_layers=2)
# Out:
# Enter dimensions of linear layers:
# Enter your last layer

# %%
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

# %%
m,acc, lo, val_ac, val_lo = run_XBNET(x_train,x_test,y_train,y_test,model,criterion,optimizer,epochs=20,batch_size=32)
# Out:
# Percentage training completed:   5%|▌         | 1/20 [00:02<00:52,  2.77s/it]Training Loss after epoch 1 is 1.7598567008972168 and Accuracy is 33.333333333333336
# Validation Loss after epoch 1 is 1.2603492736816406 and Accuracy is 30.0
# Percentage training completed:  10%|█         | 2/20 [00:05<00:44,  2.46s/it]Training Loss after epoch 2 is 1.127474457025528 and Accuracy is 34.166666666666664
# Validation Loss after epoch 2 is 1.0621721744537354 and Accuracy is 26.666666666666668
# Percentage training completed:  15%|█▌        | 3/20 [00:06<00:37,  2.18s/it]Training Loss after epoch 3 is 0.9731206148862839 and Accuracy is 41.666666666666664
# Validation Loss after epoch 3 is 0.9330022931098938 and Accuracy is 46.666666666666664
# Percentage training completed:  20%|██        | 4/20 [00:11<00:48,  3.06s/it]Training Loss after epoch 4 is 0.8655844330787659 and Accuracy is 40.833333333333336
# Validation Loss after epoch 4 is 0.8444578647613525 and Accuracy is 46.666666666666664
# Percentage training completed:  25%|██▌       | 5/20 [00:16<00:56,  3.75s/it]Training Loss after epoch 5 is 0.8124025017023087 and Accuracy is 60.0
# Validation Loss after epoch 5 is 0.7475191950798035 and Accuracy is 83.33333333333333
# Percentage training completed:  30%|███       | 6/20 [00:22<01:02,  4.50s/it]Training Loss after epoch 6 is 0.7534121125936508 and Accuracy is 96.66666666666667
# Validation Loss after epoch 6 is 0.6785233616828918 and Accuracy is 100.0
# Percentage training completed:  35%|███▌      | 7/20 [00:26<00:56,  4.36s/it]Training Loss after epoch 7 is 0.6899037510156631 and Accuracy is 86.66666666666667
# Validation Loss after epoch 7 is 0.6070489883422852 and Accuracy is 86.66666666666667
# Percentage training completed:  40%|████      | 8/20 [00:27<00:42,  3.52s/it]Training Loss after epoch 8 is 0.6353746503591537 and Accuracy is 75.0
# Validation Loss after epoch 8 is 0.5470249056816101 and Accuracy is 86.66666666666667
# Percentage training completed:  45%|████▌     | 9/20 [00:31<00:38,  3.47s/it]Training Loss after epoch 9 is 0.5909880101680756 and Accuracy is 88.33333333333333
# Validation Loss after epoch 9 is 0.49087390303611755 and Accuracy is 96.66666666666667
# Percentage training completed:  50%|█████     | 10/20 [00:33<00:30,  3.04s/it]Training Loss after epoch 10 is 0.5470462590456009 and Accuracy is 95.0
# Validation Loss after epoch 10 is 0.4420928359031677 and Accuracy is 100.0
# Percentage training completed:  55%|█████▌    | 11/20 [00:36<00:27,  3.07s/it]Training Loss after epoch 11 is 0.50543162971735 and Accuracy is 92.5
# Validation Loss after epoch 11 is 0.4004718065261841 and Accuracy is 93.33333333333333
# Percentage training completed:  60%|██████    | 12/20 [00:38<00:22,  2.76s/it]Training Loss after epoch 12 is 0.4756005257368088 and Accuracy is 91.66666666666667
# Validation Loss after epoch 12 is 0.3677302300930023 and Accuracy is 93.33333333333333
# Percentage training completed:  65%|██████▌   | 13/20 [00:41<00:18,  2.66s/it]Training Loss after epoch 13 is 0.4510582983493805 and Accuracy is 95.0
# Validation Loss after epoch 13 is 0.3416294753551483 and Accuracy is 100.0
# Percentage training completed:  70%|███████   | 14/20 [00:47<00:22,  3.68s/it]Training Loss after epoch 14 is 0.42750973999500275 and Accuracy is 96.66666666666667
# Validation Loss after epoch 14 is 0.3188863694667816 and Accuracy is 100.0
# Percentage training completed:  75%|███████▌  | 15/20 [00:51<00:19,  3.83s/it]Training Loss after epoch 15 is 0.40748099237680435 and Accuracy is 95.0
# Validation Loss after epoch 15 is 0.299813449382782 and Accuracy is 100.0
# Percentage training completed:  80%|████████  | 16/20 [00:55<00:15,  3.96s/it]Training Loss after epoch 16 is 0.3925800547003746 and Accuracy is 95.0
# Validation Loss after epoch 16 is 0.28358155488967896 and Accuracy is 100.0
# Percentage training completed:  85%|████████▌ | 17/20 [00:59<00:11,  3.96s/it]Training Loss after epoch 17 is 0.37840550392866135 and Accuracy is 96.66666666666667
# Validation Loss after epoch 17 is 0.2692892849445343 and Accuracy is 100.0
# Percentage training completed:  90%|█████████ | 18/20 [01:02<00:07,  3.78s/it]Training Loss after epoch 18 is 0.3643917664885521 and Accuracy is 96.66666666666667
# Validation Loss after epoch 18 is 0.2562420666217804 and Accuracy is 100.0
# Percentage training completed:  95%|█████████▌| 19/20 [01:05<00:03,  3.41s/it]Training Loss after epoch 19 is 0.3526910990476608 and Accuracy is 96.66666666666667
# Validation Loss after epoch 19 is 0.24452124536037445 and Accuracy is 100.0
# Percentage training completed: 100%|██████████| 20/20 [01:07<00:00,  3.39s/it]Training Loss after epoch 20 is 0.34209170937538147 and Accuracy is 96.66666666666667
# Validation Loss after epoch 20 is 0.23376668989658356 and Accuracy is 100.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        37
#            1       1.00      0.90      0.95        42
#            2       0.91      1.00      0.95        41
#
#     accuracy                           0.97       120
#    macro avg       0.97      0.97      0.97       120
# weighted avg       0.97      0.97      0.97       120
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        13
#            1       1.00      1.00      1.00         8
#            2       1.00      1.00      1.00         9
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30
#
# Validation Loss after epoch 20 is 0.23376668989658356 and Accuracy is 100.0

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.plot(acc,label='training accuracy')
plt.plot(val_ac,label = 'validation accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()

plt.subplot(1,2,2)
plt.plot(lo,label='training loss')
plt.plot(val_lo,label = 'validation loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend();

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=de072003-a9db-4342-8067-19a4b45feff1' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
